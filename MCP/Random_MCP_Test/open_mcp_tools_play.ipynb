# %%
# Show Python Version
# !python --version
# Out:
# Python 3.13.2

# %%
# !pip install mcp-people-finder
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 728.6/728.6 kB 11.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 14.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20/20 [mcp-people-finder]fastmcp]]lue-aio]
# ...

# %%
# !pip show mcp-people-finder
# Out:
# Name: mcp-people-finder
# Version: 0.1.0
# Summary: Enterprise-grade People Finder MCP Server
# Home-page:
# Author: Mayank Tripathi
# Author-email:
# License:
# Location: /Users/tripathimachine/miniconda3/lib/python3.13/site-packages
# Requires: fastmcp, mcp, python-dotenv
# Required-by:

# %%
# Use the folder name, not the pip name
import people_finder

print(people_finder.mcp)

# %% [markdown]
# Test:

# %%
from people_finder.server import mcp
# from people_finder.server.mcp import search_employee 

# FastMCP tools can be called directly for testing
import asyncio

async def test():
    result = await mcp.search_employee("Alice Smith")
    # result = await search_employee("Alice Smith")
    print(result)

asyncio.run(test())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 # from people_finder.server import mcp
# ----> 2 from people_finder.server.mcp import search_employee
#       3
#       4 # FastMCP tools can be called directly for testing
#       5 import asyncio
#
# ModuleNotFoundError: No module named 'people_finder.server.mcp'; 'people_finder.server' is not a package

# %%
from people_finder.server import mcp

# print(mcp)

# List all attributes of the mcp object to find available tools
print(dir(mcp)) 


# # # List available tools
# print(mcp.tool)
# for tool_name in dir(mcp.tool):
#     print(f"Tool: {tool_name}")
#     if not tool_name.startswith("_"):
#         print(tool_name)

# print(mcp.list_tools())
# for tool in mcp.list_tools():
#     print(f"Tool: {tool}")

# List names of tools registered in the FastMCP instance
# print(f"Tools available: {list(mcp._tools.keys())}")
# Out:
# ['__annotations__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', '_auth_server_provider', '_custom_starlette_routes', '_event_store', '_mcp_server', '_normalize_path', '_prompt_manager', '_resource_manager', '_retry_interval', '_session_manager', '_setup_handlers', '_token_verifier', '_tool_manager', 'add_prompt', 'add_resource', 'add_tool', 'call_tool', 'completion', 'custom_route', 'dependencies', 'get_context', 'get_prompt', 'icons', 'instructions', 'list_prompts', 'list_resource_templates', 'list_resources', 'list_tools', 'name', 'prompt', 'read_resource', 'remove_tool', 
# ...

# %%
# To actually 'use' one without an agent:
import asyncio
async def manual_test():
    # You call the tool name just like a function on the mcp object
    result = await mcp.search_employee(name="Alice")
    print(result)

asyncio.run(manual_test())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[26], line 8
#       4     # You call the tool name just like a function on the mcp object
#       5     result = await mcp.search_employee(name="Alice")
#       6     print(result)
#       7
# ----> 8 asyncio.run(manual_test())
#
# File ~/miniconda3/lib/python3.13/asyncio/runners.py:191, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    187     asyncio.run(main())
#     188 """
#     189 if events._get_running_loop() is not None:
#     190     # fail fast with short traceback
# --> 191     raise RuntimeError(
#     192         "asyncio.run() cannot be called from a running event loop")
#     194 with Runner(debug=debug, loop_factory=loop_factory) as runner:
# ...
